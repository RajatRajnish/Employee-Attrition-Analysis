# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Rajat Rajnish/Ana Pyth projects/employee attrition/employee_attrition_dataset_10000.csv')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
# ...

# %%
#----Finding null values----

# %%
null_val=df.isnull()
print(null_val.sum())
# Out:
# Employee_ID                      0
# Age                              0
# Gender                           0
# Marital_Status                   0
# Department                       0
# Job_Role                         0
# Job_Level                        0
# Monthly_Income                   0
# Hourly_Rate                      0
# Years_at_Company                 0
# Years_in_Current_Role            0
# Years_Since_Last_Promotion       0
# Work_Life_Balance                0
# Job_Satisfaction                 0
# Performance_Rating               0
# Training_Hours_Last_Year         0
# Overtime                         0
# Project_Count                    0
# Average_Hours_Worked_Per_Week    0
# Absenteeism                      0
# Work_Environment_Satisfaction    0
# Relationship_with_Manager        0
# Job_Involvement                  0
# Distance_From_Home               0
# Number_of_Companies_Worked       0
# Attrition                        0
# dtype: int64

# %%
pd.options.display.max_columns=500
df
# Out:
#       Employee_ID  Age  Gender Marital_Status Department   Job_Role  \
# 0               1   58    Male         Single    Finance    Manager
# 1               2   48  Female       Divorced         HR  Assistant
# 2               3   34  Female        Married  Marketing    Manager
# 3               4   27  Female       Divorced         HR    Manager
# 4               5   40    Male        Married         HR    Analyst
# ...           ...  ...     ...            ...        ...        ...
# 9995         9996   22  Female       Divorced  Marketing    Manager
# 9996         9997   35  Female       Divorced  Marketing  Executive
# 9997         9998   23    Male       Divorced         IT    Manager
# 9998         9999   42  Female         Single  Marketing    Manager
# 9999        10000   39  Female       Divorced    Finance  Executive
#
#       Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  \
# 0             5            7332           81                24
# ...

# %%
df['Department'].unique()
# Out:
# array(['Finance', 'HR', 'Marketing', 'Sales', 'IT'], dtype=object)

# %%
df['Job_Role'].unique()
# Out:
# array(['Manager', 'Assistant', 'Analyst', 'Executive'], dtype=object)

# %%
#-------converting object to string datatypes---------

# %%
df['Attrition']=df['Attrition'].astype('object')
df['Gender']=df['Gender'].astype('string')
df['Overtime']=df['Overtime'].astype('string')

# %%
avg_sal=df.groupby('Job_Role')['Monthly_Income'].mean()
avg_sal
# Out:
# Job_Role
# Analyst      11476.202177
# Assistant    11416.573286
# Executive    11410.872779
# Manager      11442.332643
# Name: Monthly_Income, dtype: float64

# %%
plt.figure(figsize=(10,6))
avg_sal.plot(kind='bar',color='skyblue')
plt.title('Avg Salary Vs Job Role')
plt.show()

# %%
job_sat=df.groupby('Job_Role')['Job_Satisfaction'].mean()
plt.figure(figsize=(6,4))
job_sat.plot(kind='bar',color='orange')
plt.title('Job_satisfaction Vs Job Role')
plt.show()

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    5042
# Male      4958
# Name: count, dtype: Int64

# %%
gen_perf=df.groupby('Gender')['Performance_Rating'].mean()
plt.figure(figsize=(6,4))
gen_perf.plot(kind='bar',color='yellow',edgecolor='black')
plt.title('Gender Vs Performance_Rating')
plt.show()

# %%
#------Binary:Attrition,Gender,Overtime-------

# %%
df['Attrition']=df['Attrition'].apply(lambda x: 1 if x == "Yes" else 0)
df['Gender']=df['Gender'].apply(lambda x: 1 if x == "Male" else 0)
df['Overtime']=df['Overtime'].apply(lambda x: 1 if x == "Yes" else 0)
df
# Out:
#       Employee_ID  Age  Gender Marital_Status Department   Job_Role  \
# 0               1   58       1         Single    Finance    Manager
# 1               2   48       0       Divorced         HR  Assistant
# 2               3   34       0        Married  Marketing    Manager
# 3               4   27       0       Divorced         HR    Manager
# 4               5   40       1        Married         HR    Analyst
# ...           ...  ...     ...            ...        ...        ...
# 9995         9996   22       0       Divorced  Marketing    Manager
# 9996         9997   35       0       Divorced  Marketing  Executive
# 9997         9998   23       1       Divorced         IT    Manager
# 9998         9999   42       0         Single  Marketing    Manager
# 9999        10000   39       0       Divorced    Finance  Executive
#
#       Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# ...

# %%
attrition_rate = df['Attrition'].value_counts(normalize=True) * 100
print(attrition_rate)
# Out:
# Attrition
# 0    80.03
# 1    19.97
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Attrition', data=df,color='Cyan',edgecolor='black')
plt.title("Attrition")
plt.show()

# %%
#--------Attrition by Department-----------------

# %%
dept_attr=df.groupby('Department')['Attrition'].value_counts().unstack()
dept_attr
plt.bar(dept_attr.index,dept_attr[0], label='No Attrition')
plt.bar(dept_attr.index,dept_attr[1],bottom=dept_attr[0], label='Attrition')
plt.xlabel('Departments')
plt.ylabel('No.of Employees')
plt.title('Attrition by Department')
plt.legend()
plt.show()

# %%
#----Attrition By Age-----------

# %%
age_attr=df.groupby('Age')['Attrition'].value_counts().unstack()
age_attr
plt.figure(figsize=(12,8))
plt.bar(age_attr.index,age_attr[0],label='No Attrition')
plt.bar(age_attr.index,age_attr[1],bottom=age_attr[0],label='Attrition')
plt.xlabel('Age')
plt.ylabel('No.of Employees')
plt.title('Attrition by Age')
plt.legend()
plt.show()

# %%
#----Attrition by Job Role------

# %%
jb_attr=df.groupby('Job_Role')['Attrition'].value_counts().unstack()
jb_attr
plt.figure(figsize=(8,5))
plt.bar(jb_attr.index,jb_attr[0],label='No Attrition')
plt.bar(jb_attr.index,jb_attr[1],bottom=jb_attr[0],label='Attrition')
plt.xlabel('Job Role')
plt.ylabel('No.of Employees')
plt.title('Attrition by Job Role')
plt.legend()
plt.show()

# %%
#------Attrition by Job satisifaction rating---------

# %%
jbs_attr=df.groupby('Job_Satisfaction')['Attrition'].value_counts().unstack()

plt.figure(figsize=(8,5))
plt.bar(jbs_attr.index,jbs_attr[0],label='No Attrition')
plt.bar(jbs_attr.index,jbs_attr[1],bottom=jbs_attr[0],label='Attrition')
plt.xlabel('Job Role')
plt.ylabel('No.of Employees')
plt.title('Attrition by Job Role')
plt.legend()
plt.show()

# %%
jbs_attr

# %%
#------Attrition on Distance from Home-----------

# %%
dt_attr=df.groupby('Distance_From_Home')['Attrition'].value_counts().unstack()

plt.figure(figsize=(12,8))
plt.bar(dt_attr.index,dt_attr[0],label='No Attrition')
plt.bar(dt_attr.index,dt_attr[1],bottom=dt_attr[0],label='Attrition')
plt.xlabel('Distance from home')
plt.ylabel('No.of Employees')
plt.title('Attrition by Distance from home')
plt.legend()
plt.show()

# %%
#----one-hot Encoding:Department,Job_Role,Marital_Status

# %%
df=df.join(pd.get_dummies(df['Department'],prefix='Department')).drop('Department',axis=1)
df=df.join(pd.get_dummies(df['Job_Role'],prefix='Job_Role')).drop('Job_Role',axis=1)
df=df.join(pd.get_dummies(df['Marital_Status'],prefix='Marital_Status')).drop('Marital_Status',axis=1)

# %%
df
# Out:
#       Employee_ID  Age  Gender  Job_Level  Monthly_Income  Hourly_Rate  \
# 0               1   58       1          5            7332           81
# 1               2   48       0          4            6069           55
# 2               3   34       0          4           11485           65
# 3               4   27       0          4           18707           28
# 4               5   40       1          1           16398           92
# ...           ...  ...     ...        ...             ...          ...
# 9995         9996   22       0          5            4276           27
# 9996         9997   35       0          3           10327           60
# 9997         9998   23       1          3           12592           68
# 9998         9999   42       0          3            9287           26
# 9999        10000   39       0          2            7225           54
#
#       Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# ...

# %%
df=df.map(lambda x: 1 if x is True else 0 if x is False else x)

# %%
df
# Out:
#       Employee_ID  Age  Gender  Job_Level  Monthly_Income  Hourly_Rate  \
# 0               1   58       1          5            7332           81
# 1               2   48       0          4            6069           55
# 2               3   34       0          4           11485           65
# 3               4   27       0          4           18707           28
# 4               5   40       1          1           16398           92
# ...           ...  ...     ...        ...             ...          ...
# 9995         9996   22       0          5            4276           27
# 9996         9997   35       0          3           10327           60
# 9997         9998   23       1          3           12592           68
# 9998         9999   42       0          3            9287           26
# 9999        10000   39       0          2            7225           54
#
#       Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# ...

# %%
df=df.drop('Employee_ID', axis=1)

# %%
df.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X,y = df.drop('Attrition',axis=1), df['Attrition']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

model= RandomForestClassifier(n_jobs=-1)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
model.score(X_test,y_test)
# Out:
# 0.823

# %%
sorted_imp=dict(sorted(zip(model.feature_names_in_, model.feature_importances_), key= lambda x: x[1], reverse=True))
sorted_imp
# Out:
# {'Monthly_Income': 0.07803798501453614,
#  'Hourly_Rate': 0.06953243515700872,
#  'Training_Hours_Last_Year': 0.06894675898807576,
#  'Distance_From_Home': 0.06306097454740119,
#  'Age': 0.06306061893306053,
#  'Average_Hours_Worked_Per_Week': 0.06002748769065335,
#  'Years_at_Company': 0.058989310882617794,
#  'Absenteeism': 0.05542653420340363,
#  'Years_in_Current_Role': 0.04966473772592987,
#  'Years_Since_Last_Promotion': 0.04279602685510793,
#  'Project_Count': 0.04148321429730281,
#  'Job_Satisfaction': 0.029485092051114905,
#  'Job_Level': 0.028934461759533802,
#  'Relationship_with_Manager': 0.02645622713665362,
#  'Performance_Rating': 0.025933309942634108,
#  'Job_Involvement': 0.025710995743751987,
#  'Number_of_Companies_Worked': 0.025696179413821567,
#  'Work_Environment_Satisfaction': 0.025378242221817296,
#  'Work_Life_Balance': 0.02443260661846212,
#  'Overtime': 0.012778725247735913,
#  'Gender': 0.012284972361526975,
# ...

# %%
plt.figure(figsize=(20,8))

plt.bar(sorted_imp.keys(),sorted_imp.values(),color='coral')
plt.xticks(rotation=45,ha='right')
plt.show()
